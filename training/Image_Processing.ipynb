# %%
# !pip install opencv-python
# Out:
# ...
#      ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#      ---------------------------------------- 0.3/38.2 MB 9.6 MB/s eta 0:00:04
#       --------------------------------------- 0.6/38.2 MB 9.9 MB/s eta 0:00:04
#      - -------------------------------------- 1.0/38.2 MB 9.0 MB/s eta 0:00:05
#      - -------------------------------------- 1.3/38.2 MB 9.3 MB/s eta 0:00:04
#      - -------------------------------------- 1.6/38.2 MB 9.5 MB/s eta 0:00:04
#      -- ------------------------------------- 2.0/38.2 MB 9.6 MB/s eta 0:00:04
#      -- ------------------------------------- 2.3/38.2 MB 9.3 MB/s eta 0:00:04
#      -- ------------------------------------- 2.7/38.2 MB 9.5 MB/s eta 0:00:04
#      --- ------------------------------------ 3.0/38.2 MB 9.1 MB/s eta 0:00:04
#      --- ------------------------------------ 3.4/38.2 MB 9.4 MB/s eta 0:00:04
#      --- ------------------------------------ 3.7/38.2 MB 9.1 MB/s eta 0:00:04
# ...

# %%
# Import opencv
import cv2

# Import Operating System
import os

# %% [markdown]
# # Setup Folders

# %%
labels = ['basketball_in_hoop', 'jumpshot']

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# #  Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# ...
#      ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#      - -------------------------------------- 0.3/6.8 MB 7.9 MB/s eta 0:00:01
#      --- ------------------------------------ 0.6/6.8 MB 7.2 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.9/6.8 MB 7.7 MB/s eta 0:00:01
#      ------ --------------------------------- 1.2/6.8 MB 8.4 MB/s eta 0:00:01
#      -------- ------------------------------- 1.5/6.8 MB 8.6 MB/s eta 0:00:01
#      ---------- ----------------------------- 1.8/6.8 MB 8.0 MB/s eta 0:00:01
#      ------------ --------------------------- 2.1/6.8 MB 8.2 MB/s eta 0:00:01
#      ------------- -------------------------- 2.4/6.8 MB 8.3 MB/s eta 0:00:01
#      --------------- ------------------------ 2.7/6.8 MB 8.1 MB/s eta 0:00:01
#      ----------------- ---------------------- 3.0/6.8 MB 8.2 MB/s eta 0:00:01
#      ------------------- -------------------- 3.3/6.8 MB 8.4 MB/s eta 0:00:01
# ...

# %%
# !pip list
# Out:
# Package            Version
# ------------------ --------
# asttokens          2.2.1
# backcall           0.2.0
# colorama           0.4.6
# comm               0.1.2
# debugpy            1.6.6
# decorator          5.1.1
# executing          1.2.0
# importlib-metadata 6.0.0
# ipykernel          6.21.2
# ipython            8.11.0
# jedi               0.18.2
# jupyter_client     8.0.3
# jupyter_core       5.2.0
# lxml               4.9.2
# matplotlib-inline  0.1.6
# nest-asyncio       1.5.6
# numpy              1.24.2
# opencv-python      4.7.0.72
# packaging          23.0
# parso              0.8.3
# pickleshare        0.7.5
# pip                23.0.1
# platformdirs       3.0.0
# prompt-toolkit     3.0.38
# psutil             5.9.4
# pure-eval          0.2.2
# Pygments           2.14.0
# PyQt5              5.15.9
# PyQt5-Qt5          5.15.2
# PyQt5-sip          12.11.1
# python-dateutil    2.8.2
# pywin32            305
# pyzmq              25.0.0
# setuptools         58.1.0
# ...

# %%
LABELING_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
# Installs image labelling software
if not os.path.exists(LABELING_PATH):
    # !mkdir {LABELING_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELING_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
# !cd {LABELING_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# OPen labelImg program
# !cd {LABELING_PATH} && python labelImg.py

# %% [markdown]
# # Separate by Training and Testing
